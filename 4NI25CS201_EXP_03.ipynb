# %% [markdown]
# <a href="https://colab.research.google.com/github/2025cssumankumarig-cpu/dav_lab1/blob/main/4NI25CS201_EXP_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
df=pd.read_csv('/content/Student.csv')
df.head()
# Out:
#   Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0       S147    Male                    31        68.267841                86
# 1       S136    Male                    16        78.222927                73
# 2       S209  Female                    21        87.525096                74
# 3       S458  Female                    27        92.076483                99
# 4       S078  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail
# 0                63      Pass
# 1                50      Fail
# 2                55      Fail
# 3                65      Pass
# 4                70      Pass

# %%
print("missing values before handling:")
print(df.isnull().sum())
# Out:
# missing values before handling:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              0
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df.loc[0:5,'Study_Hours_per_Week ']=None
df.loc[0:5,'Attendance_Rate ']=None
df.loc[0:5,'Past_Exam_Scores']=None
df.loc[0:5,'Final_Exam_Score ']=None
print(df.isnull().sum().sum()>0)
# Out:
# True

# %%
df['Study_Hours_per_Week ']=df['Study_Hours_per_Week'].fillna(df['Study_Hours_per_Week'].mean())

# %%
df['Attendance_Rate ']=df['Attendance_Rate'].fillna(df['Attendance_Rate'].median())

# %%
df['Past_Exam_Scores']=df['Past_Exam_Scores'].ffill()

# %%
df['Final_Exam_Score ']=df['Final_Exam_Score'].fillna(df['Final_Exam_Score'].mean())
print("\nMissing values after imputation:")
print(df.isnull().sum())
# Out:
# Missing values after imputation:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              6
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Final_Exam_Score              0
# dtype: int64

# %%
df=pd.get_dummies(df,columns=['Parental_Education_Level'])
print("\nOne-Hot Encoded columns")
print(df.columns.tolist())
# Out:
# One-Hot Encoded columns
# ['Student_ID', 'Gender', 'Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Internet_Access_at_Home', 'Extracurricular_Activities', 'Final_Exam_Score', 'Pass_Fail', 'Study_Hours_per_Week ', 'Attendance_Rate ', 'Final_Exam_Score ', 'Parental_Education_Level_Bachelors', 'Parental_Education_Level_High School', 'Parental_Education_Level_Masters', 'Parental_Education_Level_PhD']

# %%
le=LabelEncoder()
df['Pass_Fail_Encoded']=le.fit_transform(df['Pass_Fail'])
print("\nEncoded column")
print(df[['Pass_Fail','Pass_Fail_Encoded']].head())
# Out:
# Encoded column
#   Pass_Fail  Pass_Fail_Encoded
# 0      Pass                  1
# 1      Fail                  0
# 2      Fail                  0
# 3      Pass                  1
# 4      Pass                  1

# %%
df['Gender_Encoded']=le.fit_transform(df['Gender'])
df['Internet_Access_at_Home']=le.fit_transform(df['Internet_Access_at_Home'])
df['Extracurricular_Encoded']=le.fit_transform(df['Extracurricular_Activities'])

# %%
df.to_csv("student_performance_cleaned.csv",index=False)
print("\nCleaned dataset saved as 'student_performance_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'student_performance_cleaned.csv'
